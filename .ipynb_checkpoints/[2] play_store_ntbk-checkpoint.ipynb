# %%
import sys 

# !pip install -U google-play-scraper
# !pip install -U tzlocal
# Out:
# Collecting google-play-scraper
#   Downloading google-play-scraper-1.0.0.tar.gz (52 kB)
#      |████████████████████████████████| 52 kB 959 kB/s  eta 0:00:01
# Building wheels for collected packages: google-play-scraper
#   Building wheel for google-play-scraper (setup.py) ... done
#   Created wheel for google-play-scraper: filename=google_play_scraper-1.0.0-py3-none-any.whl size=24069 sha256=a1fd2f3e491c3e9c8f2943e33ff5c6c6b59c4186a60c3060d661738b5d41846d
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/5c/22/78/b708165d9158a7c96e65cb15e6ab57e537417f81db7afa68e4
# Successfully built google-play-scraper
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.0.0
# Requirement already satisfied: tzlocal in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (2.1)
# Requirement already satisfied: pytz in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tzlocal) (2021.1)

# %% [markdown]
# ## Scrape Google Play Store reviews using the google_play_scraper library
#
# Homepage: https://github.com/JoMingyu/google-play-scraper
#
# ---

# %%
import pandas as pd

# for scraping app info and reviews from Google Play
from google_play_scraper import app, Sort, reviews

# for pretty printing data structures
from pprint import pprint

# for keeping track of timing
import datetime as dt
from tzlocal import get_localzone

# for building in wait times
import random
import time

# %%
app_name = 'GCash'
app_id = 'com.globe.gcash.android'
    
# Get start time
start = dt.datetime.now(tz=get_localzone())
fmt= "%m/%d/%y - %T %p"    

# Print starting output for app
print('---'*20)
print('---'*20)    
print(f'***** {app_name} started at {start.strftime(fmt)}')
print()

# Empty list for storing reviews
app_reviews = []

# Number of reviews to scrape per batch
count = 200

# To keep track of how many batches have been completed
batch_num = 0


# Retrieve reviews (and continuation_token) with reviews function
rvws, token = reviews(
    app_id,           # found in app's url
    lang='en',        # defaults to 'en'
    country='ph',     # defaults to 'us'
    sort=Sort.NEWEST, # start with most recent
    count=count,       # batch size
#     filter_score_with=5 # defaults to None(means all score)
)


# Add the list of review dicts to overall list
app_reviews.extend(rvws)

# Increase batch count by one
batch_num +=1 
print(f'Batch {batch_num} completed.')

# convert list of review dictionaries to a dataframe
gps_df = pd.DataFrame(app_reviews)

# Wait 20 to 30 seconds to start next batch
time.sleep(random.randint(3, 5))

# Append review IDs to list prior to starting next batch
pre_review_ids = []
for rvw in app_reviews:
    pre_review_ids.append(rvw['reviewId'])

# Loop through at most max number of batches
for batch in range(1000):
    rvws, token = reviews( # store continuation_token
        app_id,
        lang='en',
        country='ph',
        sort=Sort.NEWEST,
        count=count,
        continuation_token=token, # using token obtained from previous batch
        filter_score_with=5 # defaults to None(means all score)
    )

    # Append unique review IDs from current batch to new list
    new_review_ids = []
    for r in rvws:
        new_review_ids.append(r['reviewId'])

    # Add the list of review dicts to main app_reviews list
    app_reviews.extend(rvws)

    # Increase batch count by one
    batch_num +=1

    # Break loop and stop scraping for current app if most recent batch
      # did not add any unique reviews
    all_review_ids = pre_review_ids + new_review_ids
    if len(set(pre_review_ids)) == len(set(all_review_ids)):
        print(f'No reviews left to scrape. Completed {batch_num} batches.\n')
        break

    # all_review_ids becomes pre_review_ids to check against 
      # for next batch
    pre_review_ids = all_review_ids

    # At every 100th batch
    if batch_num%100==0:

        # print update on number of batches
        print(f'Batch {batch_num} completed.')

        # print update about num reviews inserted
        store_time = dt.datetime.now(tz=get_localzone())
        print(f"""
        Successfully inserted {len(app_reviews)} {app_name} 
        reviews into collection at {store_time.strftime(fmt)}.\n
        """)

#         # empty our list for next round of 100 batches
#         app_reviews = []

    # Wait 20 to 30 seconds to start next batch
    time.sleep(random.randint(3, 5))

# Print update when max number of batches has been reached
  # OR when last batch didn't add any unique reviews
print(f'Done scraping {app_name}.')
print(f'Scraped a total of {len(set(pre_review_ids))} unique reviews.\n')

# Append new reviews to main dataframe
gps_df = gps_df.append(app_reviews, ignore_index=True)

# Get end time
end = dt.datetime.now(tz=get_localzone())

# Print ending output for app
print(f"""
Successfully inserted all {app_name} reviews into collection
at {end.strftime(fmt)}.\n
""")
print(f'Time elapsed for {app_name}: {end-start}')
print('---'*20)
print('---'*20)
print('\n')
# Out:
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** GCash started at 06/29/21 - 07:14:08 AM
#
# Batch 1 completed.
# Batch 100 completed.
#
#         Successfully inserted 20000 GCash
#         reviews into collection at 06/29/21 - 07:21:36 AM.
#
#
# Batch 200 completed.
#
#         Successfully inserted 40000 GCash
#         reviews into collection at 06/29/21 - 07:28:46 AM.
#
#
# Batch 300 completed.
#
#         Successfully inserted 60000 GCash
#         reviews into collection at 06/29/21 - 07:36:30 AM.
#
#
# Batch 400 completed.
#
#         Successfully inserted 80000 GCash
#         reviews into collection at 06/29/21 - 07:43:51 AM.
#
#
# Batch 500 completed.
#
#         Successfully inserted 100000 GCash
#         reviews into collection at 06/29/21 - 07:51:16 AM.
#
#
# Batch 600 completed.
#
#         Successfully inserted 120000 GCash
#         reviews into collection at 06/29/21 - 07:58:26 AM.
#
#
# Batch 700 completed.
#
#         Successfully inserted 140000 GCash
#         reviews into collection at 06/29/21 - 08:05:45 AM.
#
#
# Batch 800 completed.
#
#         Successfully inserted 160000 GCash
#         reviews into collection at 06/29/21 - 08:13:02 AM.
#
#
# Batch 900 completed.
#
#         Successfully inserted 180000 GCash
#         reviews into collection at 06/29/21 - 08:20:20 AM.
#
#
# Batch 1000 completed.
#
#         Successfully inserted 200000 GCash
#         reviews into collection at 06/29/21 - 08:27:36 AM.
#
#
# Done scraping GCash.
# Scraped a total of 200200 unique reviews.
#
#
# Successfully inserted all GCash reviews into collection
# at 06/29/21 - 08:27:47 AM.
#
#
# Time elapsed for GCash: 1:13:38.947691
# ------------------------------------------------------------
# ------------------------------------------------------------

# %%
gps_df.sort_values(by=['at'])
# Out:
#                                                  reviewId       userName  \
# 200399  gp:AOqpTOELbSkDtb9NTlndkvmXLuflSeNzdhA_hzhUD2o...  A Google user
# 200398  gp:AOqpTOFDqWs7RnpCWi0U9t0l9LoSL0ZjbugTAG5vt8o...    negarox 101
# 200397  gp:AOqpTOExpk5QcFFJdoW7r90TCWMDkzd_yg-wY2WmD61...  A Google user
# 200396  gp:AOqpTOFqxoJmC2BoPPoNXPugseb5IQfP20PlBR60MPy...      Red Trend
# 200395  gp:AOqpTOFMTYo3hTachF5d4gcP0hmw8ev2VPRbefRvOVy...          NA LC
# ...                                                   ...            ...
# 202     gp:AOqpTOFsVXlN-qPIW_52nD2g8NKVVmuiYffkWolf3Ju...  Jerome Guillo
# 1       gp:AOqpTOEYUDwNcT2XO38wK2F6LCKXfmfsdiSkcExbBLj...     Ninoy Pron
# 201     gp:AOqpTOEYUDwNcT2XO38wK2F6LCKXfmfsdiSkcExbBLj...     Ninoy Pron
# 200     gp:AOqpTOGgPbObgmDtkh_6s74KV5Jq5AxLs9CbANJ4yKt...   Janine Arrio
# 0       gp:AOqpTOGgPbObgmDtkh_6s74KV5Jq5AxLs9CbANJ4yKt...   Janine Arrio
#
#                                                 userImage  \
# 200399  https://play-lh.googleusercontent.com/EGemoI2N...
# 200398  https://play-lh.googleusercontent.com/a-/AOh14...
# 200397  https://play-lh.googleusercontent.com/EGemoI2N...
# 200396  https://play-lh.googleusercontent.com/a-/AOh14...
# 200395  https://play-lh.googleusercontent.com/a-/AOh14...
# ...                                                   ...
# 202     https://play-lh.googleusercontent.com/a-/AOh14...
# 1       https://play-lh.googleusercontent.com/a-/AOh14...
# 201     https://play-lh.googleusercontent.com/a-/AOh14...
# 200     https://play-lh.googleusercontent.com/a/AATXAJ...
# 0       https://play-lh.googleusercontent.com/a/AATXAJ...
#
#                                                   content  score  \
# 200399                                          Excellent      5
# 200398           GCASH APP. Is easy to used . great app .      5
# 200397                                        Very useful      5
# 200396                                   Its worth a try.      5
# 200395  HELPFUL SA LAHAT ANG GCASH.. PERO BAKIT SA MES...      5
# ...                                                   ...    ...
# 202     Ok kaayu sya bai. Great app. Skip the long que...      5
# 1                                                      Ok      5
# 201                                                    Ok      5
# 200                                       It's so awesome      5
# 0                                         It's so awesome      5
#
#         thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 200399              0                 None 2018-11-23 12:39:28         None
# 200398              0                 None 2018-11-23 12:49:54         None
# 200397              0               5.10.1 2018-11-23 13:14:24         None
# 200396              0                5.2.1 2018-11-23 13:30:45         None
# 200395              0               5.10.1 2018-11-23 14:47:15         None
# ...               ...                  ...                 ...          ...
# 202                 0               5.40.0 2021-06-29 06:47:14         None
# 1                   0                 None 2021-06-29 06:56:59         None
# 201                 0                 None 2021-06-29 06:56:59         None
# 200                 0               5.26.2 2021-06-29 06:57:10         None
# 0                   0               5.26.2 2021-06-29 06:57:10         None
#
#        repliedAt
# 200399       NaT
# 200398       NaT
# 200397       NaT
# 200396       NaT
# 200395       NaT
# ...          ...
# 202          NaT
# 1           None
# 201          NaT
# 200          NaT
# 0           None
#
# [200400 rows x 10 columns]

# %%
# get review data from January 1, 2020 (12 AM) until June 3, 2021 (12 AM)
mask = (gps_df['at'] > '2020-01-01 00:00:00') & (gps_df['at'] < '2021-06-04 00:00:00')
complete_df = gps_df.loc[mask]
complete_df.sort_values(by=['at'])
# Out:
#                                                  reviewId           userName  \
# 148005  gp:AOqpTOHzwS4Zt07IpcjdzaYEokevuJ3qWV7tKOmkZzt...      Miriam Javier
# 148004  gp:AOqpTOH039aUNokVUQY3HbgE9zPfHPph8U6k-H7Vbk1...      Nelson Virtus
# 148003  gp:AOqpTOE9vKOFEoLNN900Wwuid2T1RwonR1-FJDzw_iR...        Arnel Trono
# 148002  gp:AOqpTOFzPui58AHexouXqqE_fmFIL5xP-kvdUwv6S4Y...     Gerald Aguilar
# 148001  gp:AOqpTOH8Nm3rM0WhtcoY7SMRgYF_moiGgCm4tPtFrTL...   Clarrise Mijares
# ...                                                   ...                ...
# 11959   gp:AOqpTOFPthSWOyCdspYO4msEGh8m_1WvAxsSIwp5lbn...     Maener Cabuhat
# 11958   gp:AOqpTOH6Q1tJB1n05fQMvgqTMmqM-oyf7sa5bNepev5...         Karen Jane
# 11957   gp:AOqpTOG5j8qKnSyhjK_Zn4OlMF8MnRO9g1pHNqdV5sm...     Glena may Pike
# 11956   gp:AOqpTOH20galiBvWhl3m298Li5x8y3MpLqg0l91poCm...  rosemarie maranga
# 11955   gp:AOqpTOEVZM7O4S3tlg-7ErSrskN-7IwxtxvPydElWv-...      Juvelyn Plaza
#
#                                                 userImage  \
# 148005  https://play-lh.googleusercontent.com/a/AATXAJ...
# 148004  https://play-lh.googleusercontent.com/a-/AOh14...
# 148003  https://play-lh.googleusercontent.com/a-/AOh14...
# 148002  https://play-lh.googleusercontent.com/a-/AOh14...
# 148001  https://play-lh.googleusercontent.com/a/AATXAJ...
# ...                                                   ...
# 11959   https://play-lh.googleusercontent.com/a/AATXAJ...
# 11958   https://play-lh.googleusercontent.com/a/AATXAJ...
# 11957   https://play-lh.googleusercontent.com/a-/AOh14...
# 11956   https://play-lh.googleusercontent.com/a-/AOh14...
# 11955   https://play-lh.googleusercontent.com/a/AATXAJ...
#
#                                                   content  score  \
# 148005  Please fix your app bug. It has been to weeks ...      2
# 148004  I always wanted to cash in for me to use it on...      1
# 148003                                               Nice      5
# 148002                                            Awesome      5
# 148001  Pahelp nmn po dq maaus yung gcash mpin q dhil ...      1
# ...                                                   ...    ...
# 11959                                           excellent      5
# 11958                                           excellent      5
# 11957   Super ganda nung app. daming tulong nito sakin...      5
# 11956                                                  ok      5
# 11955                                            Its good      5
#
#         thumbsUpCount reviewCreatedVersion                  at  \
# 148005              0               5.24.0 2020-01-01 00:04:48
# 148004              0               5.24.0 2020-01-01 00:45:51
# 148003              0               5.14.0 2020-01-01 00:54:16
# 148002              0                 None 2020-01-01 01:20:27
# 148001              0               5.20.2 2020-01-01 02:09:35
# ...               ...                  ...                 ...
# 11959               0               5.40.0 2021-06-03 23:46:52
# 11958               0               5.40.0 2021-06-03 23:48:37
# 11957               0               5.40.0 2021-06-03 23:52:33
# 11956               0               5.40.0 2021-06-03 23:53:29
# 11955               0                 None 2021-06-03 23:55:25
#
#                                              replyContent            repliedAt
# 148005                                               None                  NaT
# 148004  Hi! We are sorry to hear about your concern. P...  2020-01-01 13:31:55
# 148003                                               None                  NaT
# 148002                                               None                  NaT
# 148001  Hi! We are sorry to hear about your concern. P...  2020-01-01 13:31:52
# ...                                                   ...                  ...
# 11959                                                None                  NaT
# 11958                                                None                  NaT
# 11957                                                None                  NaT
# 11956                                                None                  NaT
# 11955                                                None                  NaT
#
# [136051 rows x 10 columns]

# %% [markdown]
# ## Export reviews dataframe as a csv file
# ---

# %%
complete_df.to_csv('data/complete_play_store_reviews.csv', index=False)

# %%
# get all 1-star and 5-star reviews from the main dataframe and transfer them to a new one
filtered_df = complete_df[(complete_df.score == 1) | (complete_df.score == 5)]
filtered_df.sort_values(by=['at'])
# Out:
#                                                  reviewId           userName  \
# 136049  gp:AOqpTOH039aUNokVUQY3HbgE9zPfHPph8U6k-H7Vbk1...      Nelson Virtus
# 136048  gp:AOqpTOE9vKOFEoLNN900Wwuid2T1RwonR1-FJDzw_iR...        Arnel Trono
# 136047  gp:AOqpTOFzPui58AHexouXqqE_fmFIL5xP-kvdUwv6S4Y...     Gerald Aguilar
# 136046  gp:AOqpTOH8Nm3rM0WhtcoY7SMRgYF_moiGgCm4tPtFrTL...   Clarrise Mijares
# 136045  gp:AOqpTOFjhUQfxEVrdMJqif7cENAfQ2KiniFY7nHKbJk...     rey mandalones
# ...                                                   ...                ...
# 4       gp:AOqpTOFPthSWOyCdspYO4msEGh8m_1WvAxsSIwp5lbn...     Maener Cabuhat
# 3       gp:AOqpTOH6Q1tJB1n05fQMvgqTMmqM-oyf7sa5bNepev5...         Karen Jane
# 2       gp:AOqpTOG5j8qKnSyhjK_Zn4OlMF8MnRO9g1pHNqdV5sm...     Glena may Pike
# 1       gp:AOqpTOH20galiBvWhl3m298Li5x8y3MpLqg0l91poCm...  rosemarie maranga
# 0       gp:AOqpTOEVZM7O4S3tlg-7ErSrskN-7IwxtxvPydElWv-...      Juvelyn Plaza
#
#                                                 userImage  \
# 136049  https://play-lh.googleusercontent.com/a-/AOh14...
# 136048  https://play-lh.googleusercontent.com/a-/AOh14...
# 136047  https://play-lh.googleusercontent.com/a-/AOh14...
# 136046  https://play-lh.googleusercontent.com/a/AATXAJ...
# 136045  https://play-lh.googleusercontent.com/a-/AOh14...
# ...                                                   ...
# 4       https://play-lh.googleusercontent.com/a/AATXAJ...
# 3       https://play-lh.googleusercontent.com/a/AATXAJ...
# 2       https://play-lh.googleusercontent.com/a-/AOh14...
# 1       https://play-lh.googleusercontent.com/a-/AOh14...
# 0       https://play-lh.googleusercontent.com/a/AATXAJ...
#
#                                                   content  score  \
# 136049  I always wanted to cash in for me to use it on...      1
# 136048                                               Nice      5
# 136047                                            Awesome      5
# 136046  Pahelp nmn po dq maaus yung gcash mpin q dhil ...      1
# 136045                                             faster      5
# ...                                                   ...    ...
# 4                                               excellent      5
# 3                                               excellent      5
# 2       Super ganda nung app. daming tulong nito sakin...      5
# 1                                                      ok      5
# 0                                                Its good      5
#
#         thumbsUpCount reviewCreatedVersion                  at  \
# 136049              0               5.24.0 2020-01-01 00:45:51
# 136048              0               5.14.0 2020-01-01 00:54:16
# 136047              0                  NaN 2020-01-01 01:20:27
# 136046              0               5.20.2 2020-01-01 02:09:35
# 136045              0               5.22.1 2020-01-01 02:22:00
# ...               ...                  ...                 ...
# 4                   0               5.40.0 2021-06-03 23:46:52
# 3                   0               5.40.0 2021-06-03 23:48:37
# 2                   0               5.40.0 2021-06-03 23:52:33
# 1                   0               5.40.0 2021-06-03 23:53:29
# 0                   0                  NaN 2021-06-03 23:55:25
#
#                                              replyContent            repliedAt
# 136049  Hi! We are sorry to hear about your concern. P...  2020-01-01 13:31:55
# 136048                                                NaN                  NaN
# 136047                                                NaN                  NaN
# 136046  Hi! We are sorry to hear about your concern. P...  2020-01-01 13:31:52
# 136045                                                NaN                  NaN
# ...                                                   ...                  ...
# 4                                                     NaN                  NaN
# 3                                                     NaN                  NaN
# 2                                                     NaN                  NaN
# 1                                                     NaN                  NaN
# 0                                                     NaN                  NaN
#
# [109849 rows x 10 columns]

# %% [markdown]
# ## Export filtered reviews dataframe as a csv file
# ---

# %%
filtered_df.to_csv('data/filtered_play_store_reviews.csv', index=False)

# %% [markdown]
# ## Data exploration
# ---

# %%
complete_df = pd.read_csv('data/complete_play_store_reviews.csv')

# convert 'date' column to datetime since dtypes aren't preserved in csv files
complete_df['at'] = pd.to_datetime(complete_df['at'])
complete_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136051 entries, 0 to 136050
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              136051 non-null  object
#  1   userName              136051 non-null  object
#  2   userImage             136051 non-null  object
#  3   content               136040 non-null  object
#  4   score                 136051 non-null  int64
#  5   thumbsUpCount         136051 non-null  int64
#  6   reviewCreatedVersion  104307 non-null  object
#  7   at                    136051 non-null  datetime64[ns]
#  8   replyContent          2949 non-null    object
#  9   repliedAt             2949 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(7)
# memory usage: 10.4+ MB

# %%
import matplotlib.dates as mdates
import matplotlib.pylab as plt
import seaborn as sns

plt.style.use('fivethirtyeight')
# plt.figure(figsize=(10,8))

s = sns.displot(data=complete_df, x='at', hue='score', height=8, aspect=2, palette='Paired', kde=True)
s.set(ylabel='Review count')

# %%
s = sns.displot(data=filtered_df, x='at', hue='score', height=8, aspect=2, palette='Paired', kde=True)
s.set(ylabel='Review count')

# %% [markdown]
# ## Combine App Store and Play Store Review Data
# ---

# %% [markdown]
# ### Import CSV files

# %%
complete_as_df = pd.read_csv('data/complete_app_store_reviews.csv')
complete_gps_df = pd.read_csv('data/complete_play_store_reviews.csv')

# %%
# get review data from January 1, 2020 (12 AM) until June 3, 2021 (12 AM)
mask = (complete_as_df['date'] > '2020-01-01 00:00:00') & (complete_as_df['date'] < '2021-06-04 00:00:00')
complete_as_df = complete_as_df.loc[mask]
complete_as_df = complete_as_df.drop(['userName', 'isEdited', 'title', 'developerResponse'], axis=1)
complete_as_df['type'] = 'app store'
complete_as_df.sort_values(by=['date'])
# Out:
#                                                  review  rating  \
# 80    Gcash is a great app BUT if you tried buying s...       3
# 2647  ANDAMI NG VIDEOS SA YOUTUBE RIGHT NOW NA SCAM ...       1
# 424   I cannot log in my email account to my gcash a...       3
# 34    Been an avid user for a few years but recently...       1
# 2033  Please keep up with 2020. It’s worse than dial...       1
# ...                                                 ...     ...
# 1037  I am constantly being charged by google for so...       1
# 980   Please bring back my 300 pesos top up on your ...       3
# 2429  Difficult to get back unsuccesful payment/tran...       3
# 1659                                       Annoying Ads       1
# 1454  I have a load transaction, gCash deducted my a...       1
#
#                      date       type
# 80    2020-01-01 02:10:56  app store
# 2647  2020-01-01 11:26:33  app store
# 424   2020-01-01 15:11:30  app store
# 34    2020-01-01 19:14:19  app store
# 2033  2020-01-02 01:43:34  app store
# ...                   ...        ...
# 1037  2021-06-03 11:30:04  app store
# 980   2021-06-03 13:32:35  app store
# 2429  2021-06-03 14:27:02  app store
# 1659  2021-06-03 14:54:52  app store
# 1454  2021-06-03 18:58:26  app store
#
# [2550 rows x 4 columns]

# %%
complete_gps_df = complete_gps_df.drop(['reviewId', 'userName', 'userImage', 'thumbsUpCount', 'replyContent', 'repliedAt'], axis=1)
complete_gps_df['type'] = 'play store'
complete_gps_df.sort_values(by=['at'])
# Out:
#                                                   content  score  \
# 136050  Please fix your app bug. It has been to weeks ...      2
# 136049  I always wanted to cash in for me to use it on...      1
# 136048                                               Nice      5
# 136047                                            Awesome      5
# 136046  Pahelp nmn po dq maaus yung gcash mpin q dhil ...      1
# ...                                                   ...    ...
# 4                                               excellent      5
# 3                                               excellent      5
# 2       Super ganda nung app. daming tulong nito sakin...      5
# 1                                                      ok      5
# 0                                                Its good      5
#
#        reviewCreatedVersion                   at        type
# 136050               5.24.0  2020-01-01 00:04:48  play store
# 136049               5.24.0  2020-01-01 00:45:51  play store
# 136048               5.14.0  2020-01-01 00:54:16  play store
# 136047                  NaN  2020-01-01 01:20:27  play store
# 136046               5.20.2  2020-01-01 02:09:35  play store
# ...                     ...                  ...         ...
# 4                    5.40.0  2021-06-03 23:46:52  play store
# 3                    5.40.0  2021-06-03 23:48:37  play store
# 2                    5.40.0  2021-06-03 23:52:33  play store
# 1                    5.40.0  2021-06-03 23:53:29  play store
# 0                       NaN  2021-06-03 23:55:25  play store
#
# [136051 rows x 5 columns]

# %%
# init empty DF
complete_df = pd.DataFrame()

# populate lists
date_lst = complete_gps_df['at'].values.tolist() + complete_as_df['date'].values.tolist()
review_lst = complete_gps_df['content'].values.tolist() + complete_as_df['review'].values.tolist()
rating_lst = complete_gps_df['score'].values.tolist() + complete_as_df['rating'].values.tolist()
type_lst = complete_gps_df['type'].values.tolist() + complete_as_df['type'].values.tolist()

# populate DF
complete_df['date'] = date_lst
complete_df['date'] = pd.to_datetime(complete_df['date'])
complete_df['review'] = review_lst
complete_df['rating'] = rating_lst
complete_df['type'] = type_lst

# shuffle rows
complete_df = complete_df.sample(frac=1).reset_index(drop=True)

# drop rows that have NULL entries
complete_df = complete_df.dropna()

# drop rows that have duplicates
complete_df = complete_df.drop_duplicates()

complete_df.info()
print(display(complete_df.head(10)))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138588 entries, 0 to 138600
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    138588 non-null  datetime64[ns]
#  1   review  138588 non-null  object
#  2   rating  138588 non-null  int64
#  3   type    138588 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 5.3+ MB
#                  date                                             review  \
# 0 2020-01-24 07:41:26                                              Great
# 1 2020-04-23 02:53:36  After the last globe system upgrade, gcash sta...
# 2 2020-07-09 13:48:45                                                 Ok
# 3 2020-07-13 13:33:43             Other I.Ds button/option not appearing
# 4 2020-07-23 02:19:34                                          Efficient
# 5 2020-01-16 16:40:08                                        Very useful
# 6 2021-06-02 11:38:30                                               Good
# 7 2021-03-15 08:40:20  Almost 1 years experineced using my Gcash but ...
# 8 2020-04-06 10:59:13                 Its really great and very helpful😊
# 9 2021-04-21 22:07:41                                                ❤❤❤
#
#    rating        type
# 0       5  play store
# 1       3  play store
# 2       5  play store
# 3       1  play store
# 4       5  play store
# 5       5  play store
# 6       5  play store
# 7       5  play store
# 8       5  play store
# 9       5  play store
# None

# %% [markdown]
# ## Export complete reviews dataframe as a csv file
# ---

# %%
complete_df.to_csv('data/complete_reviews.csv', index=False)
