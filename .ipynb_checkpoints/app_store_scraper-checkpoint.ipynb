# %%
import requests
import pprint

# %%
from xml.etree import ElementTree

response = requests.get(url)

tree = ElementTree.fromstring(response.content)

# %%
import xml.etree
from xml.etree import ElementTree as ET

url = 'https://itunes.apple.com/ph/rss/customerreviews/id=520020791/sortBy=mostRecent/json'

response = requests.get(url)
# tree = ET.fromstring(response.content)

# pprint.pprint(response.json())
asd = response.json()

# %%
len(asd['feed']['entry'])
# Out:
# 50

# %%
asd['feed']['entry'][0]['im:rating']
# Out:
# {'label': '2'}

# %%
with open('qwe.xml', 'wb') as f:
    f.write(response.content)

# %%
mytree = ET.parse('qwe.xml')
myroot = mytree.getroot()
myroot
# Out:
# <Element '{http://www.w3.org/2005/Atom}feed' at 0x0000013DF559C138>

# %%
myroot = ET.fromstring(response.content)
print(myroot.tag[-4:])
print(myroot.attrib)
# Out:
# feed
# {'{http://www.w3.org/XML/1998/namespace}lang': 'en'}

# %%
for elem in mytree.iter():
    print(elem)
# Out:
# <Element '{http://www.w3.org/2005/Atom}feed' at 0x0000013DF559C138>
# <Element '{http://www.w3.org/2005/Atom}id' at 0x0000013DF559C098>
# <Element '{http://www.w3.org/2005/Atom}title' at 0x0000013DF559C318>
# <Element '{http://www.w3.org/2005/Atom}updated' at 0x0000013DF559C2C8>
# <Element '{http://www.w3.org/2005/Atom}link' at 0x0000013DF559C4A8>
# <Element '{http://www.w3.org/2005/Atom}link' at 0x0000013DF559CB88>
# <Element '{http://www.w3.org/2005/Atom}link' at 0x0000013DF559CBD8>
# <Element '{http://www.w3.org/2005/Atom}link' at 0x0000013DF559CC28>
# <Element '{http://www.w3.org/2005/Atom}link' at 0x0000013DF559CC78>
# <Element '{http://www.w3.org/2005/Atom}link' at 0x0000013DF559CCC8>
# <Element '{http://www.w3.org/2005/Atom}icon' at 0x0000013DF559CD68>
# <Element '{http://www.w3.org/2005/Atom}author' at 0x0000013DF559CE08>
# <Element '{http://www.w3.org/2005/Atom}name' at 0x0000013DF559C6D8>
# <Element '{http://www.w3.org/2005/Atom}uri' at 0x0000013DF559C778>
# <Element '{http://www.w3.org/2005/Atom}rights' at 0x0000013DF559C638>
# <Element '{http://www.w3.org/2005/Atom}entry' at 0x0000013DF559CB38>
# <Element '{http://www.w3.org/2005/Atom}updated' at 0x0000013DF559CA48>
# <Element '{http://www.w3.org/2005/Atom}id' at 0x0000013DF559CA98>
# <Element '{http://www.w3.org/2005/Atom}title' at 0x0000013DF559C9F8>
# <Element '{http://www.w3.org/2005/Atom}content' at 0x0000013DF559C958>
# <Element '{http://itunes.apple.com/rss}contentType' at 0x0000013DF559C8B8>
# <Element '{http://itunes.apple.com/rss}voteSum' at 0x0000013DF549B598>
# <Element '{http://itunes.apple.com/rss}voteCount' at 0x0000013DF549BEA8>
# <Element '{http://itunes.apple.com/rss}rating' at 0x0000013DF549BDB8>
# <Element '{http://itunes.apple.com/rss}version' at 0x0000013DF549B778>
# <Element '{http://www.w3.org/2005/Atom}author' at 0x0000013DF549BBD8>
# <Element '{http://www.w3.org/2005/Atom}name' at 0x0000013DF549B4F8>
# <Element '{http://www.w3.org/2005/Atom}uri' at 0x0000013DF549B188>
# <Element '{http://www.w3.org/2005/Atom}link' at 0x0000013DF549BA48>
# <Element '{http://www.w3.org/2005/Atom}content' at 0x0000013DF549BC28>
# <Element '{http://www.w3.org/2005/Atom}entry' at 0x0000013DF549B458>
# <Element '{http://www.w3.org/2005/Atom}updated' at 0x0000013DF549BB38>
# <Element '{http://www.w3.org/2005/Atom}id' at 0x0000013DF5559138>
# <Element '{http://www.w3.org/2005/Atom}title' at 0x0000013DF56877C8>
# <Element '{http://www.w3.org/2005/Atom}content' at 0x0000013DF5687278>
# <Element '{http://itunes.apple.com/rss}contentType' at 0x0000013DF5687368>
# <Element '{http://itunes.apple.com/rss}voteSum' at 0x0000013DF5687458>
# <Element '{http://itunes.apple.com/rss}voteCount' at 0x0000013DF5687728>
# <Element '{http://itunes.apple.com/rss}rating' at 0x0000013DF5687688>
# <Element '{http://itunes.apple.com/rss}version' at 0x0000013DF5687EF8>
# <Element '{http://www.w3.org/2005/Atom}author' at 0x0000013DF5687BD8>
# <Element '{http://www.w3.org/2005/Atom}name' at 0x0000013DF56879F8>
# <Element '{http://www.w3.org/2005/Atom}uri' at 0x0000013DF5687908>
# <Element '{http://www.w3.org/2005/Atom}link' at 0x0000013DF55E49A8>
# <Element '{http://www.w3.org/2005/Atom}content' at 0x0000013DF55E4E08>
# <Element '{http://www.w3.org/2005/Atom}entry' at 0x0000013DF55E4A98>
# <Element '{http://www.w3.org/2005/Atom}updated' at 0x0000013DF549A3B8>
# <Element '{http://www.w3.org/2005/Atom}id' at 0x0000013DF549AEA8>
# <Element '{http://www.w3.org/2005/Atom}title' at 0x0000013DF549AB38>
# <Element '{http://www.w3.org/2005/Atom}content' at 0x0000013DF549A598>
# <Element '{http://itunes.apple.com/rss}contentType' at 0x0000013DF549ABD8>
# <Element '{http://itunes.apple.com/rss}voteSum' at 0x0000013DF549AC28>
# <Element '{http://itunes.apple.com/rss}voteCount' at 0x0000013DF549AC78>
# <Element '{http://itunes.apple.com/rss}rating' at 0x0000013DF549AA48>
# <Element '{http://itunes.apple.com/rss}version' at 0x0000013DF549A868>
# <Element '{http://www.w3.org/2005/Atom}author' at 0x0000013DF549A2C8>
# <Element '{http://www.w3.org/2005/Atom}name' at 0x0000013DF549A048>
# <Element '{http://www.w3.org/2005/Atom}uri' at 0x0000013DF549A4F8>
# <Element '{http://www.w3.org/2005/Atom}link' at 0x0000013DF549A7C8>
# <Element '{http://www.w3.org/2005/Atom}content' at 0x0000013DF549A9A8>
# <Element '{http://www.w3.org/2005/Atom}entry' at 0x0000013DF549A278>
# <Element '{http://www.w3.org/2005/Atom}updated' at 0x0000013DF549A098>
# <Element '{http://www.w3.org/2005/Atom}id' at 0x0000013DF549A4A8>
# <Element '{http://www.w3.org/2005/Atom}title' at 0x0000013DF549A138>
# <Element '{http://www.w3.org/2005/Atom}content' at 0x0000013DF5484688>
# <Element '{http://itunes.apple.com/rss}contentType' at 0x0000013DF5484408>
# <Element '{http://itunes.apple.com/rss}voteSum' at 0x0000013DF5484188>
# <Element '{http://itunes.apple.com/rss}voteCount' at 0x0000013DF54848B8>
# <Element '{http://itunes.apple.com/rss}rating' at 0x0000013DF5484958>
# <Element '{http://itunes.apple.com/rss}version' at 0x0000013DF5484F98>
# <Element '{http://www.w3.org/2005/Atom}author' at 0x0000013DF5484DB8>
# <Element '{http://www.w3.org/2005/Atom}name' at 0x0000013DF54841D8>
# <Element '{http://www.w3.org/2005/Atom}uri' at 0x0000013DF5484F48>
# <Element '{http://www.w3.org/2005/Atom}link' at 0x0000013DF5484598>
# <Element '{http://www.w3.org/2005/Atom}content' at 0x0000013DF54844A8>
# <Element '{http://www.w3.org/2005/Atom}entry' at 0x0000013DF5484E58>
# <Element '{http://www.w3.org/2005/Atom}updated' at 0x0000013DF5484EA8>
# <Element '{http://www.w3.org/2005/Atom}id' at 0x0000013DF54847C8>
# <Element '{http://www.w3.org/2005/Atom}title' at 0x0000013DF54840E8>
# <Element '{http://www.w3.org/2005/Atom}content' at 0x0000013DF5484B88>
# <Element '{http://itunes.apple.com/rss}contentType' at 0x0000013DF54844F8>
# <Element '{http://itunes.apple.com/rss}voteSum' at 0x0000013DF54849F8>
# <Element '{http://itunes.apple.com/rss}voteCount' at 0x0000013DF5484BD8>
# <Element '{http://itunes.apple.com/rss}rating' at 0x0000013DF5484C78>
# <Element '{http://itunes.apple.com/rss}version' at 0x0000013DF5484138>
# <Element '{http://www.w3.org/2005/Atom}author' at 0x0000013DF5547688>
# <Element '{http://www.w3.org/2005/Atom}name' at 0x0000013DF5547D18>
# <Element '{http://www.w3.org/2005/Atom}uri' at 0x0000013DF5547818>
# <Element '{http://www.w3.org/2005/Atom}link' at 0x0000013DF5547C78>
# <Element '{http://www.w3.org/2005/Atom}content' at 0x0000013DF5547CC8>
# <Element '{http://www.w3.org/2005/Atom}entry' at 0x0000013DF5547B38>
# <Element '{http://www.w3.org/2005/Atom}updated' at 0x0000013DF55475E8>
# <Element '{http://www.w3.org/2005/Atom}id' at 0x0000013DF5547F48>
# <Element '{http://www.w3.org/2005/Atom}title' at 0x0000013DF5547A98>
# <Element '{http://www.w3.org/2005/Atom}content' at 0x0000013DF55E1F48>
# <Element '{http://itunes.apple.com/rss}contentType' at 0x0000013DF55E1908>
# <Element '{http://itunes.apple.com/rss}voteSum' at 0x0000013DF55E1EF8>
# <Element '{http://itunes.apple.com/rss}voteCount' at 0x0000013DF55E1DB8>
# <Element '{http://itunes.apple.com/rss}rating' at 0x0000013DF55E11D8>
# <Element '{http://itunes.apple.com/rss}version' at 0x0000013DF55E1228>
# <Element '{http://www.w3.org/2005/Atom}author' at 0x0000013DF55E14F8>
# <Element '{http://www.w3.org/2005/Atom}name' at 0x0000013DF55E14A8>
# <Element '{http://www.w3.org/2005/Atom}uri' at 0x0000013DF55E1408>
# <Element '{http://www.w3.org/2005/Atom}link' at 0x0000013DF55E1A48>
# <Element '{http://www.w3.org/2005/Atom}content' at 0x0000013DF55E1958>
# <Element '{http://www.w3.org/2005/Atom}entry' at 0x0000013DF55E12C8>
# <Element '{http://www.w3.org/2005/Atom}updated' at 0x0000013DF55E15E8>
# <Element '{http://www.w3.org/2005/Atom}id' at 0x0000013DF55E19A8>
# <Element '{http://www.w3.org/2005/Atom}title' at 0x0000013DF55E18B8>
# <Element '{http://www.w3.org/2005/Atom}content' at 0x0000013DF55E6E58>
# <Element '{http://itunes.apple.com/rss}contentType' at 0x0000013DF55E6638>
# <Element '{http://itunes.apple.com/rss}voteSum' at 0x0000013DF55E6368>
# <Element '{http://itunes.apple.com/rss}voteCount' at 0x0000013DF55E6728>
# <Element '{http://itunes.apple.com/rss}rating' at 0x0000013DF55E6818>
# <Element '{http://itunes.apple.com/rss}version' at 0x0000013DF55E6958>
# <Element '{http://www.w3.org/2005/Atom}author' at 0x0000013DF55E6908>
# <Element '{http://www.w3.org/2005/Atom}name' at 0x0000013DF55E68B8>
# <Element '{http://www.w3.org/2005/Atom}uri' at 0x0000013DF55E67C8>
# <Element '{http://www.w3.org/2005/Atom}link' at 0x0000013DF55E6278>
# <Element '{http://www.w3.org/2005/Atom}content' at 0x0000013DF55E6138>
# <Element '{http://www.w3.org/2005/Atom}entry' at 0x0000013DF55113B8>
# <Element '{http://www.w3.org/2005/Atom}updated' at 0x0000013DF5511098>
# <Element '{http://www.w3.org/2005/Atom}id' at 0x0000013DF5165A48>
# <Element '{http://www.w3.org/2005/Atom}title' at 0x0000013DF51657C8>
# <Element '{http://www.w3.org/2005/Atom}content' at 0x0000013DF5569638>
# <Element '{http://itunes.apple.com/rss}contentType' at 0x0000013D

# <Element '{http://itunes.apple.com/rss}voteSum' at 0x0000013DF54FEA98>
# <Element '{http://itunes.apple.com/rss}voteCount' at 0x0000013DF54FEF98>
# <Element '{http://itunes.apple.com/rss}rating' at 0x0000013DF54FEEF8>
# <Element '{http://itunes.apple.com/rss}version' at 0x0000013DF54FEEA8>
# <Element '{http://www.w3.org/2005/Atom}author' at 0x0000013DF54FEF48>
# <Element '{http://www.w3.org/2005/Atom}name' at 0x0000013DF54FEE58>
# <Element '{http://www.w3.org/2005/Atom}uri' at 0x0000013DF54FEE08>
# <Element '{http://www.w3.org/2005/Atom}link' at 0x0000013DF54FEDB8>
# <Element '{http://www.w3.org/2005/Atom}content' at 0x0000013DF54FEB38>
# <Element '{http://www.w3.org/2005/Atom}entry' at 0x0000013DF54ED368>
# <Element '{http://www.w3.org/2005/Atom}updated' at 0x0000013DF54ED3B8>
# <Element '{http://www.w3.org/2005/Atom}id' at 0x0000013DF54ED458>
# <Element '{http://www.w3.org/2005/Atom}title' at 0x0000013DF54ED4A8>
# <Element '{http://www.w3.org/2005/Atom}content' at 0x0000013DF54ED548>
# <Element '{http://itunes.apple.com/rss}contentType' at 0x0000013DF54ED638>
# <Element '{http://itunes.apple.com/rss}voteSum' at 0x0000013DF54ED688>
# <Element '{http://itunes.apple.com/rss}voteCount' at 0x0000013DF54ED6D8>
# <Element '{http://itunes.apple.com/rss}rating' at 0x0000013DF54ED728>
# <Element '{http://itunes.apple.com/rss}version' at 0x0000013DF54ED778>
# <Element '{http://www.w3.org/2005/Atom}author' at 0x0000013DF54ED7C8>
# <Element '{http://www.w3.org/2005/Atom}name' at 0x0000013DF54ED818>
# <Element '{http://www.w3.org/2005/Atom}uri' at 0x0000013DF54ED868>
# <Element '{http://www.w3.org/2005/Atom}link' at 0x0000013DF54ED908>
# <Element '{http://www.w3.org/2005/Atom}content' at 0x0000013DF54ED9A8>

# %%
myroot[2].tag
# Out:
# '{http://www.w3.org/2005/Atom}updated'

# %%
len(asd['feed']['entry'])
# Out:
# 50

# %%
import requests

headers = {
    'Accept': 'application/json',
    'Referer': 'https://apps.apple.com/us/app/mathy-cool-math-learner-games/id1476596747',
    'Authorization': 'Bearer eyJhbGciOiJFUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IldlYlBsYXlLaWQifQ.eyJpc3MiOiJBTVBXZWJQbGF5IiwiaWF0IjoxNTk2NTc1NTY4LCJleHAiOjE2MTIxMjc1Njh9.jnEuBNEVWhKGqI10W6dfhJFtYJtd74Nbu1NueZrPgYjU2K34LwXPQClcus8S9Jit5ayK5MOr0bIpcDx821RI4Q',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
}
for i in range(0,20,10):
    
    params = (
        ('l', 'en-US'),
        ('offset', f'{i}'),
        ('platform', 'web'),
        ('additionalPlatforms', 'appletv,ipad,iphone,mac'),
    )
    response = requests.get('https://amp-api.apps.apple.com/v1/catalog/us/apps/1476596747/reviews', params=params)
    data =  response.json()['data']
    for a in data:
        print(a['attributes']['rating'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-251-1b9d6cc7ea85> in <module>
#      19     response = requests.get(url)
#      20 #     data =  response.json()
# ---> 21     response.json()
#      22 #     for a in data:
#      23 #         print(a['attributes']['rating'])
#
# ~\Anaconda3\envs\project-env\lib\site-packages\requests\models.py in json(self, **kwargs)
#     890                     # used.
#     891                     pass
# --> 892         return complexjson.loads(self.text, **kwargs)
#     893
#     894     @property
#
# ~\Anaconda3\envs\project-env\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda3\envs\project-env\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\envs\project-env\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
