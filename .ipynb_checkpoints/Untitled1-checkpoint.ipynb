# %% [markdown]
# ## Scrape Google Play Store reviews
# ---

# %%
import sys 

# !{sys.executable} -m pip install google-play-scraper
# !{sys.executable} -m pip install tzlocal
# Out:
# Requirement already satisfied: google-play-scraper in c:\users\matthewkent.regalado\anaconda3\envs\project-env\lib\site-packages (1.0.0)

# %%
import pandas as pd

# for scraping app info and reviews from Google Play
from google_play_scraper import app, Sort, reviews

# for pretty printing data structures
from pprint import pprint

# for keeping track of timing
import datetime as dt
from tzlocal import get_localzone

# for building in wait times
import random
import time

# %%
app_name = 'GCash'
app_id = 'com.globe.gcash.android'
    
# Get start time
start = dt.datetime.now(tz=get_localzone())
fmt= "%m/%d/%y - %T %p"    

# Print starting output for app
print('---'*20)
print('---'*20)    
print(f'***** {app_name} started at {start.strftime(fmt)}')
print()

# Empty list for storing reviews
app_reviews = []

# Number of reviews to scrape per batch
count = 200

# To keep track of how many batches have been completed
batch_num = 0


# Retrieve reviews (and continuation_token) with reviews function
rvws, token = reviews(
    app_id,           # found in app's url
    lang='en',        # defaults to 'en'
    country='ph',     # defaults to 'us'
    sort=Sort.NEWEST, # start with most recent
    count=count,       # batch size
    filter_score_with=1 # defaults to None(means all score)
)


# Add the list of review dicts to overall list
app_reviews.extend(rvws)

# Increase batch count by one
batch_num +=1 
print(f'Batch {batch_num} completed.')

# convert list of review dictionaries to a dataframe
gps_df = pd.DataFrame(app_reviews)

# Wait 20 to 30 seconds to start next batch
time.sleep(random.randint(10, 15))

# Append review IDs to list prior to starting next batch
pre_review_ids = []
for rvw in app_reviews:
    pre_review_ids.append(rvw['reviewId'])

# Loop through at most max number of batches
for batch in range(200):
    rvws, token = reviews( # store continuation_token
        app_id,
        lang='en',
        country='ph',
        sort=Sort.NEWEST,
        count=count,
        continuation_token=token, # using token obtained from previous batch
        filter_score_with=1 # defaults to None(means all score)
    )

    # Append unique review IDs from current batch to new list
    new_review_ids = []
    for r in rvws:
        new_review_ids.append(r['reviewId'])

    # Add the list of review dicts to main app_reviews list
    app_reviews.extend(rvws)

    # Increase batch count by one
    batch_num +=1

    # Break loop and stop scraping for current app if most recent batch
      # did not add any unique reviews
    all_review_ids = pre_review_ids + new_review_ids
    if len(set(pre_review_ids)) == len(set(all_review_ids)):
        print(f'No reviews left to scrape. Completed {batch_num} batches.\n')
        break

    # all_review_ids becomes pre_review_ids to check against 
      # for next batch
    pre_review_ids = all_review_ids

    # At every 100th batch
    if batch_num%10==0:

        # print update on number of batches
        print(f'Batch {batch_num} completed.')

        # print update about num reviews inserted
        store_time = dt.datetime.now(tz=get_localzone())
        print(f"""
        Successfully inserted {len(app_reviews)} {app_name} 
        reviews into collection at {store_time.strftime(fmt)}.\n
        """)

#         # empty our list for next round of 100 batches
#         app_reviews = []

    # Wait 20 to 30 seconds to start next batch
    time.sleep(random.randint(10, 15))

# Print update when max number of batches has been reached
  # OR when last batch didn't add any unique reviews
print(f'Done scraping {app_name}.')
print(f'Scraped a total of {len(set(pre_review_ids))} unique reviews.\n')

# Append new reviews to main dataframe
gps_df = gps_df.append(app_reviews, ignore_index=True)

# Get end time
end = dt.datetime.now(tz=get_localzone())

# Print ending output for app
print(f"""
Successfully inserted all {app_name} reviews into collection
at {end.strftime(fmt)}.\n
""")
print(f'Time elapsed for {app_name}: {end-start}')
print('---'*20)
print('---'*20)
print('\n')
# Out:
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** GCash started at 06/04/21 - 19:15:32 PM
#
# Batch 1 completed.
# Batch 10 completed.
#
#         Successfully inserted 2000 GCash
#         reviews into collection at 06/04/21 - 19:16:21 PM.
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Anaconda3\envs\project-env\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1350                           encode_chunked=req.has_header('Transfer-encoding'))
#    1351             except OSError as err: # timeout error
#
# ~\Anaconda3\envs\project-env\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1276         """Send a complete request to the server."""
# -> 1277         self._send_request(method, url, body, headers, encode_chunked)
#    1278
#
# ~\Anaconda3\envs\project-env\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1322             body = _encode(body, 'body')
# -> 1323         self.endheaders(body, encode_chunked=encode_chunked)
#    1324
#
# ~\Anaconda3\envs\project-env\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1271             raise CannotSendHeader()
# -> 1272         self._send_output(message_body, encode_chunked=encode_chunked)
#    1273
#
# ~\Anaconda3\envs\project-env\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1031         del self._buffer[:]
# -> 1032         self.send(msg)
#    1033
#
# ~\Anaconda3\envs\project-env\lib\http\client.py in send(self, data)
#     971             if self.auto_open:
# --> 972                 self.connect()
#     973             else:
#
# ~\Anaconda3\envs\project-env\lib\http\client.py in connect(self)
#    1438
# -> 1439             super().connect()
#    1440
#
# ~\Anaconda3\envs\project-env\lib\http\client.py in connect(self)
#     943         self.sock = self._create_connection(
# --> 944             (self.host,self.port), self.timeout, self.source_address)
#     945         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~\Anaconda3\envs\project-env\lib\socket.py in create_connection(address, timeout, source_address)
#     727         try:
# --> 728             raise err
#     729         finally:
#
# ~\Anaconda3\envs\project-env\lib\socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-76-260493f939b6> in <module>
#      60         count=count,
#      61         continuation_token=token, # using token obtained from previous batch
# ---> 62         filter_score_with=1 # defaults to None(means all score)
#      63     )
#      64
#
# ~\Anaconda3\envs\project-env\lib\site-packages\google_play_scraper\features\reviews.py in reviews(app_id, lang, country, sort, count, filter_score_with, continuation_token)
#      83         try:
#      84             review_items, token = _fetch_review_items(
# ---> 85                 url, app_id, sort, _count, filter_score_with, token
#      86             )
#      87         except (TypeError, IndexError):
#
# ~\Anaconda3\envs\project-env\lib\site-packages\google_play_scraper\features\reviews.py in _fetch_review_items(url, app_id, sort, count, filter_score_with, pagination_token)
#      43             pagination_token,
#      44         ),
# ---> 45         {"content-type": "application/x-www-form-urlencoded"},
#      46     )
#      47
#
# ~\Anaconda3\envs\project-env\lib\site-packages\google_play_scraper\utils\request.py in post(url, data, headers)
#      22
#      23 def post(url: str, data: Union[str, bytes], headers: dict) -> str:
# ---> 24     return _urlopen(Request(url, data=data, headers=headers))
#      25
#      26
#
# ~\Anaconda3\envs\project-env\lib\site-packages\google_play_scraper\utils\request.py in _urlopen(obj)
#       9 def _urlopen(obj):
#      10     try:
# ---> 11         resp = urlopen(obj)
#      12     except HTTPError as e:
#      13         if e.code == 404:
#
# ~\Anaconda3\envs\project-env\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\envs\project-env\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\Anaconda3\envs\project-env\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~\Anaconda3\envs\project-env\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\envs\project-env\lib\urllib\request.py in https_open(self, req)
#    1391         def https_open(self, req):
#    1392             return self.do_open(http.client.HTTPSConnection, req,
# -> 1393                 context=self._context, check_hostname=self._check_hostname)
#    1394
#    1395         https_request = AbstractHTTPHandler.do_request_
#
# ~\Anaconda3\envs\project-env\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1350                           encode_chunked=req.has_header('Transfer-encoding'))
#    1351             except OSError as err: # timeout error
# -> 1352                 raise URLError(err)
#    1353             r = h.getresponse()
#    1354         except:
#
# URLError: <urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond>

# %%
gps_df.sort_values(by=['at'])
# Out:
#                                                reviewId  \
# 4399  gp:AOqpTOH83ytb9EaYwfNkPhN9jn4Pnqk2qqb--w7qMLq...
# 4398  gp:AOqpTOF6978YafD0p3TZaVdBkTL0zE5Ev5_frJ0KRsT...
# 4397  gp:AOqpTOG7ZzVW43WgZXBJoG_bE2APYNEcKJdAUa3LLdd...
# 4396  gp:AOqpTOF4wY_FfThVepsisKtbWStpYOK-chyuv6PPdeR...
# 4395  gp:AOqpTOHuqAGgzFZVTxcInD_KKgdAhX3QVXd9t9071fr...
# ...                                                 ...
# 202   gp:AOqpTOEDDrxsqfu1BDS2oJEsCc1EjmjfPuQ0_Qfi6_c...
# 1     gp:AOqpTOEVVxC-qpzK4KIpHwUTsCoBD9GJwmRr335PuTV...
# 201   gp:AOqpTOEVVxC-qpzK4KIpHwUTsCoBD9GJwmRr335PuTV...
# 200   gp:AOqpTOHSOrxo0ZIYMmDzNE9eIwogfevhbMvvK-SqkKQ...
# 0     gp:AOqpTOHSOrxo0ZIYMmDzNE9eIwogfevhbMvvK-SqkKQ...
#
#                      userName  \
# 4399  Patricia Nicole Lambert
# 4398         Michael Perfecio
# 4397                Ema Soñas
# 4396           Yolly Dabandan
# 4395          Jenelyn Diarios
# ...                       ...
# 202               Tori Aquino
# 1            Joselito Manalad
# 201          Joselito Manalad
# 200             A Google user
# 0               A Google user
#
#                                               userImage  \
# 4399  https://play-lh.googleusercontent.com/a-/AOh14...
# 4398  https://play-lh.googleusercontent.com/a-/AOh14...
# 4397  https://play-lh.googleusercontent.com/a-/AOh14...
# 4396  https://play-lh.googleusercontent.com/a-/AOh14...
# 4395  https://play-lh.googleusercontent.com/a-/AOh14...
# ...                                                 ...
# 202   https://play-lh.googleusercontent.com/a/AATXAJ...
# 1     https://play-lh.googleusercontent.com/a/AATXAJ...
# 201   https://play-lh.googleusercontent.com/a/AATXAJ...
# 200   https://play-lh.googleusercontent.com/EGemoI2N...
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                 content  score  thumbsUpCount  \
# 4399  At first this app is good. But now? I can't re...      1              1
# 4398  Disappointing. I trasferred Cash from my BPI A...      1              0
# 4397             Puro update😤😤😤palagi nlng error system      1              0
# 4396               Bkit diko sya maopen loading lng sya      1              0
# 4395  Sana Naman po may paraan para ma fully verifie...      1              0
# ...                                                 ...    ...            ...
# 202   I didnt get any authentication code,how could ...      1              0
# 1                                                    Ok      1              0
# 201                                                  Ok      1              0
# 200                                                  Ok      1              0
# 0                                                    Ok      1              0
#
#      reviewCreatedVersion                  at replyContent repliedAt
# 4399               5.39.1 2021-04-12 14:23:16         None       NaT
# 4398               5.39.1 2021-04-12 14:26:21         None       NaT
# 4397               5.37.0 2021-04-12 14:29:52         None       NaT
# 4396               5.38.1 2021-04-12 14:30:17         None       NaT
# 4395               5.38.1 2021-04-12 14:30:56         None       NaT
# ...                   ...                 ...          ...       ...
# 202                5.40.0 2021-06-04 18:57:05         None       NaT
# 1                  5.37.0 2021-06-04 19:01:57         None       NaT
# 201                5.37.0 2021-06-04 19:01:57         None       NaT
# 200                5.41.0 2021-06-04 19:02:55         None       NaT
# 0                  5.41.0 2021-06-04 19:02:55         None       NaT
#
# [4400 rows x 10 columns]

# %%
asd_df = gps_df
asd_df.drop_duplicates()
# Out:
#                                                  reviewId  \
# 0       gp:AOqpTOFYzXkeYpU0b4EJOZDSGbnck-BVZKmcVCB2rwo...
# 1       gp:AOqpTOFs1TfHX3rC5OOzSqTPZy6XveVjaBv7KSSfNbj...
# 2       gp:AOqpTOEVUSkwKeKxOwFJfiWwU_l1KK8MN2vPRzlBysW...
# 3       gp:AOqpTOGN8otsBdWWDqG1FWPUnLsiy6LpXjRC6lqa2sO...
# 4       gp:AOqpTOHxbH_wLsJ4zJjM3C_2GZyHS-p36yA5Rl13yjP...
# ...                                                   ...
# 110195  gp:AOqpTOGe-WKaslLTP43zOOwwV79gQhEdChpXHGZaHHj...
# 110196  gp:AOqpTOHNaX4Zv4KgSAu9Ren1HOFLLpghimdQ2gYn__G...
# 110197  gp:AOqpTOEuMsYD3eImHQuyP-RvrGCJ82ow_MB-j9_ZrMF...
# 110198  gp:AOqpTOEDkwyEHTzPcHtTNLbGRhNhtqTTbGuN1UCadPH...
# 110199  gp:AOqpTOH7yELkSYa8f-eQRc0Jq0s-u9PerZ8v3UsSWYm...
#
#                     userName  \
# 0           Mylene I Bollido
# 1                       MyMy
# 2               rose panidar
# 3                jade abella
# 4          John Isaac Laroya
# ...                      ...
# 110195            uno Gascon
# 110196  Jasniyah M Manalocon
# 110197       Sherwin Mendoza
# 110198        Hailey Delfino
# 110199            Aleya Meru
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/AATXAJ...
# 1       https://play-lh.googleusercontent.com/a-/AOh14...
# 2       https://play-lh.googleusercontent.com/a-/AOh14...
# 3       https://play-lh.googleusercontent.com/a-/AOh14...
# 4       https://play-lh.googleusercontent.com/a-/AOh14...
# ...                                                   ...
# 110195  https://play-lh.googleusercontent.com/a-/AOh14...
# 110196  https://play-lh.googleusercontent.com/a-/AOh14...
# 110197  https://play-lh.googleusercontent.com/a-/AOh14...
# 110198  https://play-lh.googleusercontent.com/a/AATXAJ...
# 110199  https://play-lh.googleusercontent.com/a/AATXAJ...
#
#                                                   content  score  \
# 0                              hindi ko mabuksan gcash ko      1
# 1       No one's replying to my email. I created a tic...      1
# 2       since the latest update i can't open the app a...      1
# 3                                       I cant install gg      1
# 4       Gscore is not INCREASING anymore Now I Cant us...      1
# ...                                                   ...    ...
# 110195  I need to update my email,gcash send the codes...      1
# 110196                                               nice      1
# 110197  Useless.... I have never reached max limit and...      1
# 110198                                       Taas ng fees      1
# 110199  I can't fully verify my account since there's ...      1
#
#         thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 0                   0               5.40.0 2021-06-04 17:20:55         None
# 1                   0               5.41.0 2021-06-04 17:04:27         None
# 2                   0               5.41.0 2021-06-04 17:04:01         None
# 3                   0                 None 2021-06-04 17:04:00         None
# 4                   0                5.1.0 2021-06-04 16:55:40         None
# ...               ...                  ...                 ...          ...
# 110195              0               5.30.2 2020-07-27 09:19:23         None
# 110196              0               5.30.2 2020-07-27 08:55:05         None
# 110197              0               5.30.2 2020-07-27 08:53:56         None
# 110198              0                 None 2020-07-27 08:52:21         None
# 110199              0                 None 2020-07-27 08:46:24         None
#
#        repliedAt
# 0            NaT
# 1            NaT
# 2            NaT
# 3            NaT
# 4            NaT
# ...          ...
# 110195       NaT
# 110196       NaT
# 110197       NaT
# 110198       NaT
# 110199       NaT
#
# [20200 rows x 10 columns]

# %%
from google_play_scraper import reviews_all

app_name = 'GCash'
app_id = 'com.globe.gcash.android'

# scrape all 1-star reviews
gps_one_star_reviews = reviews_all(
    app_id,
    sleep_milliseconds=random.randint(10000, 20000), # defaults to 0
    lang='en', # defaults to 'en'
    country='ph', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
    filter_score_with=1 # defaults to None(means all score)
)

# %%
gps_five_star_reviews = reviews_all(
    app_id,
    sleep_milliseconds=random.randint(3000, 5000), # defaults to 0
    lang='en', # defaults to 'en'
    country='ph', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
    filter_score_with=5 # defaults to None(means all score)
)

# %%
# convert list of review dictionaries to a dataframe
gps_df = pd.DataFrame(gps_reviews)
gps_df.sort_values(by=['at'])

# %%
# Retrieve reviews (and continuation_token) with reviews function
app_id = 'com.globe.gcash.android'

# rvws, token = reviews(
#     app_id,           # found in app's url
#     lang='en',        # defaults to 'en'
#     country='ph',     # defaults to 'us'
#     sort=Sort.NEWEST, # start with most recent
#     count=200,      # batch size
#     filter_score_with=1 # defaults to None(means all score)
# )

# df = pd.DataFrame(rvws)

# To keep track of how many batches have been completed
batch_num = 0

app_reviews = []

# Loop through at most max number of batches
for batch in range(5):
    # Retrieve reviews (and continuation_token) with reviews function
    rvws, token = reviews(
        app_id,           # found in app's url
        lang='en',        # defaults to 'en'
        country='us',     # defaults to 'us'
        sort=Sort.NEWEST, # start with most recent
        count=count       # batch size
    )

    # Add the list of review dicts to overall list
    app_reviews.extend(rvws)

    # Increase batch count by one
    batch_num +=1 
    print(f'Batch {batch_num} completed.')

    # Wait 1 to 5 seconds to start next batch
    time.sleep(random.randint(3, 5))
# Out:
# Batch 1 completed.
# Batch 2 completed.
# Batch 3 completed.
# Batch 4 completed.
# Batch 5 completed.

# %%
df = pd.DataFrame(app_reviews)

# %%
df.sort_values(by=['at'], ascending=False)
# Out:
#                                               reviewId            userName  \
# 0    gp:AOqpTOH5qWAsKwB_W8qlkSNx9ZaHAo97sbOOqnkzv7D...      Kush Rodriguez
# 400  gp:AOqpTOH5qWAsKwB_W8qlkSNx9ZaHAo97sbOOqnkzv7D...      Kush Rodriguez
# 800  gp:AOqpTOH5qWAsKwB_W8qlkSNx9ZaHAo97sbOOqnkzv7D...      Kush Rodriguez
# 600  gp:AOqpTOH5qWAsKwB_W8qlkSNx9ZaHAo97sbOOqnkzv7D...      Kush Rodriguez
# 200  gp:AOqpTOH5qWAsKwB_W8qlkSNx9ZaHAo97sbOOqnkzv7D...      Kush Rodriguez
# ..                                                 ...                 ...
# 799  gp:AOqpTOFwlnV-N277IHc-DEmOCV1A6d3CHtJOy0KRQGi...  Eddie boy Reyteran
# 199  gp:AOqpTOFwlnV-N277IHc-DEmOCV1A6d3CHtJOy0KRQGi...  Eddie boy Reyteran
# 399  gp:AOqpTOFwlnV-N277IHc-DEmOCV1A6d3CHtJOy0KRQGi...  Eddie boy Reyteran
# 599  gp:AOqpTOFwlnV-N277IHc-DEmOCV1A6d3CHtJOy0KRQGi...  Eddie boy Reyteran
# 999  gp:AOqpTOFwlnV-N277IHc-DEmOCV1A6d3CHtJOy0KRQGi...  Eddie boy Reyteran
#
#                                              userImage      content  score  \
# 0    https://play-lh.googleusercontent.com/a/AATXAJ...        great      5
# 400  https://play-lh.googleusercontent.com/a/AATXAJ...        great      5
# 800  https://play-lh.googleusercontent.com/a/AATXAJ...        great      5
# 600  https://play-lh.googleusercontent.com/a/AATXAJ...        great      5
# 200  https://play-lh.googleusercontent.com/a/AATXAJ...        great      5
# ..                                                 ...          ...    ...
# 799  https://play-lh.googleusercontent.com/a/AATXAJ...  Puro update      1
# 199  https://play-lh.googleusercontent.com/a/AATXAJ...  Puro update      1
# 399  https://play-lh.googleusercontent.com/a/AATXAJ...  Puro update      1
# 599  https://play-lh.googleusercontent.com/a/AATXAJ...  Puro update      1
# 999  https://play-lh.googleusercontent.com/a/AATXAJ...  Puro update      1
#
#      thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 0                0               5.40.0 2021-06-04 13:44:44         None
# 400              0               5.40.0 2021-06-04 13:44:44         None
# 800              0               5.40.0 2021-06-04 13:44:44         None
# 600              0               5.40.0 2021-06-04 13:44:44         None
# 200              0               5.40.0 2021-06-04 13:44:44         None
# ..             ...                  ...                 ...          ...
# 799              0               5.40.0 2021-06-04 11:08:26         None
# 199              0               5.40.0 2021-06-04 11:08:26         None
# 399              0               5.40.0 2021-06-04 11:08:26         None
# 599              0               5.40.0 2021-06-04 11:08:26         None
# 999              0               5.40.0 2021-06-04 11:08:26         None
#
#     repliedAt
# 0        None
# 400      None
# 800      None
# 600      None
# 200      None
# ..        ...
# 799      None
# 199      None
# 399      None
# 599      None
# 999      None
#
# [1000 rows x 10 columns]
